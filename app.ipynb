# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Example of importing dataset

df = pd.read_csv('data/PSA_ADAS_W3_FC_2022-09-01_14-49_0054.MF4/Group_340.csv')

# %%
plt.plot(df['t'],df['Hunter_GPS_Mode'])
