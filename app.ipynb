# %%
import pandas as pd

# %%
#Example of importing dataset

df = pd.read_csv('../SW Challenge 2022 - dataset/PSA_ADAS_W3_FC_2022-09-01_14-49_0054.MF4/Group_340.csv')

print(df.to_string())
# Out:
#                 t  Hunter_GPS_Mode
# 0        0.099797                0
# 1        0.109744                0
# 2        0.119731                0
# 3        0.129779                0
# 4        0.139875                0
# 5        0.149797                0
# 6        0.159746                0
# 7        0.169730                0
# 8        0.179779                0
# 9        0.189888                0
# 10       0.199824                0
# 11       0.209764                0
# 12       0.219723                0
# 13       0.229734                0
# 14       0.239861                0
# 15       0.249802                0
# 16       0.259713                0
# 17       0.269724                0
# 18       0.279745                0
# 19       0.289883                0
# 20       0.299826                0
# 21       0.309728                0
# 22       0.319729                0
# 23       0.329742                0
# 24       0.339872                0
# 25       0.349801                0
# ...
